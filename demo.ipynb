# %%
# %pip list
# Out:
# Package                               Version
# ------------------------------------- ---------
# aiohttp                               3.8.1
# aiosignal                             1.2.0
# ansiwrap                              0.8.4
# anyio                                 3.5.0
# appdirs                               1.4.4
# argon2-cffi                           21.3.0
# argon2-cffi-bindings                  21.2.0
# arrow                                 1.2.2
# asn1crypto                            1.5.1
# async-timeout                         4.0.2
# asynctest                             0.13.0
# attrs                                 21.4.0
# Babel                                 2.9.1
# backcall                              0.2.0
# backports.functools-lru-cache         1.6.4
# beatrix-jupyterlab                    3.1.7
# beautifulsoup4                        4.10.0
# binaryornot                           0.4.4
# black                                 22.1.0
# ...

# %%
import pandas as pd
import numpy as np

# %%
pip install tensorflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 497.5/497.5 MB 1.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 KB 98.5 kB/s eta 0:00:00a 0:00:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 98.1 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 76.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 71.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 KB 12.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.5/462.5 KB 48.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 99.9 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 82.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv ('data.csv')

# %%
df.head()
# Out:
#    Temperature - (Celsius)   Year     Month
# 0                  7.72768   1901   January
# 1                  8.93600   1901  February
# 2                 16.96320   1901     March
# 3                 21.27410   1901     April
# 4                 26.04970   1901       May
